# %%
import pandas as pd
from io import StringIO
Data = '{"employee_name":"shreya", "email":"shr@gmail.com", "job_profile":[{"title1":"Team Lead","title2":"Developer"}] }'
df=pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name          email                                     job_profile
# 0        shreya  shr@gmail.com  {'title1': 'Team Lead', 'title2': 'Developer'}

# %%
df.to_json() ##convert dataFrame into Json
# Out:
# '{"employee_name":{"0":"shreya"},"email":{"0":"shr@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"shreya","email":"shr@gmail.com","job_profile":{"title1":"Team Lead","title2":"Developer"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_name":"shreya","email":"shr@gmail.com","job_profile":{"title1":"Team Lead","title2":"Developer"}}]'
