# %% [markdown]
# seaborn : python visualization library based on matplotlib
# -provides a hige-level interface
# -helps in creating complex visualizations with just a few lines of code.

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
##basic ploting with seaborn
sns.load_dataset('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 ##basic ploting with seaborn
# ----> 2 sales=sns.load_dataset('sales_report.csv')
#       3 sales
#
# File c:\Users\shrey\PY\venv\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'sales_report.csv' is not one of the example datasets.
