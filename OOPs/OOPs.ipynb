# %%
print("shreya")
# Out:
# shreya

# %%
class BankAccount :
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposite(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. new balance is{self.balance}")
    def withdraw(self,amount):
        if amount>self.balance:
            print("insufficient")
        else:
            self.balance-=amount
            print(f'{amount}is withdraw new amount is {self.balance}')

    def get_balace(self,balance):
        return self.balance        

account=BankAccount("shreya",500)
print(account.balance)
account.deposite(500)
print(account.deposite)

account.withdraw(50)
print(account.withdraw)

print(account.get_balance())
# Out:
# 500
# 500 is deposited. new balance is1000
# <bound method BankAccount.deposite of <__main__.BankAccount object at 0x00000139ADCE97F0>>
# 50is withdraw new amount is 950
# <bound method BankAccount.withdraw of <__main__.BankAccount object at 0x00000139ADCE97F0>>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 27
#      24 account.withdraw(50)
#      25 print(account.withdraw)
# ---> 27 print(account.get_balance())
#
# AttributeError: 'BankAccount' object has no attribute 'get_balance'
