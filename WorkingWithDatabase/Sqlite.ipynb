# %%
import sqlite3

# %%
##connect to an SQLite database
connection=sqlite3.connect('examlpe.db')
connection

# %%
cursor =connection.cursor()

# %%
##create a table
cursor.execute('''
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    age INTEGER,
    department TEXT
)
''')
##commit the changes
connection.commit()

# %%
"""cursor.execute('''
Select * from employees
''')"""
# Out:
# "cursor.execute('''\nSelect * from employees\n''')"

# %%
##insert the data
cursor.execute('''
Insert INTO employees(name,age,department)
                values('shr',23,'Data Scientist')
''')

cursor.execute('''
Insert INTO employees(name,age,department)
                values('eya',24,'Data Scientist')
''')

cursor.execute('''
Insert INTO employees(name,age,department)
                values('chh',20,'Data Scientist')
''')

cursor.execute('''
Insert INTO employees(name,age,department)
                values('aya',13,'Data Scientist')
''')

connection.commit()

# %%
cursor.execute('Select * from employees')
rows=cursor.fetchall()

##print quering data
for row in rows:
    print(row)
# Out:
# (1, 'shr', 23, 'Data Scientist')
# (2, 'shr', 23, 'Data Scientist')
# (3, 'eya', 24, 'Data Scientist')
# (4, 'chh', 20, 'Data Scientist')
# (5, 'aya', 13, 'Data Scientist')
# (6, 'shr', 23, 'Data Scientist')
# (7, 'eya', 24, 'Data Scientist')
# (8, 'chh', 20, 'Data Scientist')
# (9, 'aya', 13, 'Data Scientist')

# %%
##update the data 
cursor.execute('''
UPDATE employees
Set age = 34
where name ="shr"
''')
connection.commit()

# %%
cursor.execute('Select * from employees')
rows=cursor.fetchall()

##print quering data
for row in rows:
    print(row)
# Out:
# (1, 'shr', 34, 'Data Scientist')
# (2, 'shr', 34, 'Data Scientist')
# (3, 'eya', 24, 'Data Scientist')
# (4, 'chh', 20, 'Data Scientist')
# (5, 'aya', 13, 'Data Scientist')
# (6, 'shr', 34, 'Data Scientist')
# (7, 'eya', 24, 'Data Scientist')
# (8, 'chh', 20, 'Data Scientist')
# (9, 'aya', 13, 'Data Scientist')

# %%
##delete the data from the table
cursor.execute('''
Delete from employees
Where name='shr'
''')
connection.commit()

# %%
cursor.execute('Select * from employees')
rows=cursor.fetchall()

##print quering data
for row in rows:
    print(row)
# Out:
# (3, 'eya', 24, 'Data Scientist')
# (4, 'chh', 20, 'Data Scientist')
# (5, 'aya', 13, 'Data Scientist')
# (7, 'eya', 24, 'Data Scientist')
# (8, 'chh', 20, 'Data Scientist')
# (9, 'aya', 13, 'Data Scientist')

# %%
##sales database
connection=sqlite3.connect('sales_data.db')
cursor = connection.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS sales(
    id INTEGER PRIMARY KEY,
    DATE TEXT NOT NULL,
    PRODUCT TEXT NOT NULL,
    SALES INTEGER,
    REGION TEXT
)
''')
connection.commit()
sales_data=[
    ('2025-01-01','Product1',100, 'North'),
    ('2025-01-02','Product2',200, 'East'),
    ('2025-01-03','Product3',300, 'West'),
    ('2025-01-04','Product4',400, 'South')

]
cursor.executemany('''
INSERT INTO sales(DATE,PRODUCT,SALES,REGION)
    values(?,?,?,?)
''',sales_data)
connection.commit()

# %%
cursor.execute('Select * from sales')
rows=cursor.fetchall()

##print quering data
for row in rows:
    print(row)
# Out:
# (1, '2025-01-01', 'Product1', 100, 'North')
# (2, '2025-01-02', 'Product2', 200, 'East')
# (3, '2025-01-03', 'Product3', 300, 'West')
# (4, '2025-01-04', 'Product4', 400, 'South')

# %%
##close the connection
connection.close()
