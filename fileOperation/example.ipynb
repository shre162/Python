# %%
print("hello")
# Out:
# hello

# %%
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# hello
# hiii

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# hello
# hiii

# %%
with open('example.txt','w') as file:
    file.write('hel \n')
    file.write('hhh \n')

# %%
with open('example.txt','a') as file:
    file.write('append')

# %%
lines = ['first \n', 'second \n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
data = b'\x00\x01\x02\x03\x04'
with open('binary.bin','wb') as file:
    file.write(data)

# %%
with open('binary.bin','rb') as file:
    content = file.read()
    print(content)
# Out:
# b''

# %%
import os
new_directory = 'package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# Directory 'package' create

# %%
##listing files and directory
items = os.listdir('.')
print(items)
# Out:
# ['binary.bin', 'example.ipynb', 'example.txt', 'package']

# %%
##joining paths
dir_name='folder'
file_name='file.txt'
full_path= os.path.join(os.getcwd(),dir_name,file_name)
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 file_name='file.txt'
#       4 full_path= os.path.join(os.getcwd(),dir_name,file_name)
# ----> 5 print(full_name)
#
# NameError: name 'full_name' is not defined
