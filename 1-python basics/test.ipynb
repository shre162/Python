# %%
###python example

# %%
1+1
# Out:
# 2

# %%
name="Shreya"
Name="Chhaya"

print(name)
print(Name)
# Out:
# Shreya
# Chhaya

# %%
age=50
if age>45:
    print(age)
# Out:
# 50

# %%
total=5+5+\
5+5
print(total)
# Out:
# 20

# %%
x=5;y=6;z=x+y
print(z)
# Out:
# 11

# %%
age=23;
type(age)
print(type(age))
# Out:
# <class 'int'>

# %%
age=23;
type(age)
# Out:
# int

# %%
ag=input("what is the age")
print(age,type(age))
# Out:
# 23 <class 'int'>

# %%
num = int(input("give me the number"))

if num>0:
    print("positive")
    if num%2==0:
        print("even")
    else:
        print("odd")
else:
    print("negative or zero")
# Out:
# positive
# even

# %%
list=[]
print(type(list))
# Out:
# <class 'list'>

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
print("hello")
# Out:
# hello

# %%
num = tuple[1,2,3,4,5]
print(num)
# Out:
# tuple[1, 2, 3, 4, 5]

# %%
abc = tuple['a','b','c',1 ,2]
print(abc)
# Out:
# tuple['a', 'b', 'c', 1, 2]

# %%
my_set={1,2,3,4,5,6}
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.add(7)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
my_set.remove(5)
print(my_set)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
rem=my_set.pop()
print(rem)
print(my_set)
# Out:
# 1
# {2, 3, 4, 6, 7}

# %%
print(3 in my_set)
# Out:
# True

# %%
addition = lambda a,b : a+b
print(addition(5,6))
# Out:
# 11

# %%
even = lambda num:num%2==0
even(5)
# Out:
# False

# %%
addition = lambda x,y,z : x+y+z
addition(5,6,0)
# Out:
# 11

# %%
num=[1,2,3,4,5]

# %%
def sqr(x) :
    return x*x
sqr(10)
# Out:
# 100

# %%
numb=[1,2,3,4,5,6,7]
map(sqr,numb)

# %%
numb=[1,2,3,4,5,6,7]
map(lambda x:x*x,numb)

# %%
num=[1,2,3,4,5,6]
filter(even,num)

# %%
def even(num):
    if num%2==0:
        return true
    even(24)

# %%
print("hello")

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
# Out:
# 4.0

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
sqrt(16)
# Out:
# 4.0

# %%
"""from 1-python basic.maths import addition
addition(2,3)"""
# Out:
# 'from 1-python basic.maths import addition\naddition(2,3)'

# %%
import array 
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana']))
# Out:
# 8
# apple

# %%
#file and directory access
import os
print(os.getcwd())
# Out:
# c:\Users\shrey\PY\1-python basics

# %%
#high level operations on files and collections
import shutil
shutil.copyfile('source.txt','des.txt')
# Out:
# 'des.txt'

# %%
#data serialization
import json
data = {'name':'sh'}
jso_str=json.dump(data)
print(json_str)
print(type(json_str))
